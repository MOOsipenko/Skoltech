# %%
import numpy as np
import matplotlib.pyplot as plt

from environment import State, Environment
from environment import DEFAULT_START_ST, DEFAULT_GOAL_ST, DEFAULT_CONFIG, SIMPLE_CONFIG

# %%
st_start = State(*DEFAULT_START_ST)
st_goal = State(*DEFAULT_GOAL_ST)

# %%
st_start._center_coors
# Out:
# array([10, 10])

# %%
st_start

# %%
st_goal._angle
# Out:
# -1.5707963267948966

# %%
env = Environment.from_config(st_start, SIMPLE_CONFIG)

# %%
env.render(goal_state=State(*DEFAULT_GOAL_ST))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 env.render(goal_state=State(*DEFAULT_GOAL_ST))
#
# File ~\Skoltech\Term_2\Planning_Algorithms_in_Artificial_Intelligence\Project\Project\environment.py:134, in Environment.render(self, goal_state)
#     130 plt.ylim(0, self._env_size[1])
#     132 # render current state
#     133 plt.gca().add_patch(
# --> 134     Rectangle(
#     135         self._state._vertices[0],
#     136         State.RECT_WIDTH,
#     137         State.RECT_HEIGHT,
#     138         np.rad2deg(self._state._angle),
#     139         facecolor='red',
#     140         fill=True,
#     141     )
#     142 )
#     144 # additionally render goal state
#     145 if goal_state:
#
# TypeError: Rectangle.__init__() takes 4 positional arguments but 5 were given

# %%
env._state._center_coors
# Out:
# array([10, 10])

# %%
State(np.array([20, 20]), 90)

# %%
env._state = State(np.array([30, 30]), 90)

# %%
env.check_collision(env._state)
# Out:
# True

# %%
env.check_collision(State(np.array([30, 30]), 30))
# Out:
# True

# %%
env.render(goal_state=State(np.array([30, 30]), 30))
